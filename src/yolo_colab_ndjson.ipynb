# %%
# 安裝函數庫
# !pip install ultralytics

# %%
from ultralytics import YOLO
import nest_asyncio

nest_asyncio.apply()

# Load a model
model = YOLO("yolo26n.pt")

# Train using NDJSON dataset
results = model.train(
    data="project.ndjson",
    epochs=100,
    imgsz=640,
    device=0
)
